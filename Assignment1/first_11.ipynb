# %%
import numpy as np
import matplotlib.pyplot as plt
import random

import cv2

# %%
img=cv2.imread(r"../CIFAR-10-images-master/train/airplane/0000.jpg")
print(type(img))
print(img.shape)
print(img)
#cv2.imshow("image", img)
#cv2.waitKey(0)
plt.imshow(img)
# Out:
# <class 'numpy.ndarray'>
# (32, 32, 3)
# [[[197 202 200]
#   [199 204 202]
#   [200 205 203]
#   ...
#   [201 206 205]
#   [198 203 202]
#   [197 202 201]]
#
#  [[207 212 210]
#   [204 209 207]
#   [205 210 208]
#   ...
#   [205 210 209]
#   [203 208 207]
#   [202 207 206]]
#
#  [[211 214 212]
#   [207 210 208]
#   [211 214 212]
#   ...
#   [209 214 213]
#   [207 212 211]
#   [206 211 210]]
#
#  ...
#
#  [[221 219 219]
#   [215 213 213]
#   [195 193 193]
#   ...
#   [242 240 240]
#   [240 238 238]
#   [238 236 236]]
#
#  [[214 212 212]
#   [219 217 217]
#   [219 217 217]
#   ...
#   [249 247 247]
#   [246 244 244]
#   [239 237 237]]
#
#  [[223 221 221]
#   [223 221 221]
#   [222 220 220]
#   ...
#   [240 238 238]
#   [243 241 241]
#   [238 236 236]]]

# %%
import os
class1_path= r"../CIFAR-10-images-master/train/airplane"
cl1=[]
class2_path= r"../CIFAR-10-images-master/train/automobile"
cl2=[]
class3_path= r"../CIFAR-10-images-master/train/bird"
cl3=[]
class4_path= r"../CIFAR-10-images-master/train/cat"
cl4=[]
class5_path= r"../CIFAR-10-images-master/train/deer"
cl5=[]
class6_path= r"../CIFAR-10-images-master/train/dog"
cl6=[]
class7_path= r"../CIFAR-10-images-master/train/frog"
cl7=[]
class8_path= r"../CIFAR-10-images-master/train/horse"
cl8=[]
class9_path= r"../CIFAR-10-images-master/train/ship"
cl9=[]
class10_path= r"../CIFAR-10-images-master/train/truck"
cl10=[]


path=r"../CIFAR-10-images-master/train"
classes=['airplane','automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck' ]
classpath=[]
allimg=[]
cl0img=[]
cl1img=[]
cl2img=[]
cl3img=[]
cl4img=[]
cl5img=[]
cl6img=[]
cl7img=[]
cl8img=[]
cl9img=[]

for i in classes:
    classpath.append(os.path.join(path,i))
    
    for im in os.listdir(classpath[-1]):
        allimg.append(os.path.join(classpath[-1],im))
        if i==classes[0]:
            cl0img.append(os.path.join(classpath[0],im))
        if i==classes[1]:
            cl1img.append(os.path.join(classpath[1],im))
        if i==classes[2]:
            cl2img.append(os.path.join(classpath[2],im))
        if i==classes[3]:
            cl3img.append(os.path.join(classpath[3],im))
        if i==classes[4]:
            cl4img.append(os.path.join(classpath[4],im))
        if i==classes[5]:
            cl5img.append(os.path.join(classpath[5],im))
        if i==classes[6]:
            cl6img.append(os.path.join(classpath[6],im))
        if i==classes[7]:
            cl7img.append(os.path.join(classpath[7],im))
        if i==classes[8]:
            cl8img.append(os.path.join(classpath[8],im))
        if i==classes[9]:
            cl9img.append(os.path.join(classpath[9],im))

        
        
#print(cl4img)


# for im in os.listdir(class1_path):  # read image name from folder and append its path into "images" array     
#     cl1.append(os.path.join(class1_path,im))
# #print(cl1)

# for im in os.listdir(class2_path):  # read image name from folder and append its path into "images" array     
#     cl2.append(os.path.join(class2_path,im))
# #print(cl2)

# for im in os.listdir(class3_path):  # read image name from folder and append its path into "images" array     
#     cl3.append(os.path.join(class3_path,im))
# #print(cl3)
# for im in os.listdir(class4_path):  # read image name from folder and append its path into "images" array     
#     cl4.append(os.path.join(class4_path,im))
# #print(cl4)

# for im in os.listdir(class5_path):  # read image name from folder and append its path into "images" array     
#     cl5.append(os.path.join(class5_path,im))
# #print(cl5)

# for im in os.listdir(class6_path):  # read image name from folder and append its path into "images" array     
#     cl6.append(os.path.join(class6_path,im))
# #print(cl6)

# for im in os.listdir(class7_path):  # read image name from folder and append its path into "images" array     
#     cl7.append(os.path.join(class7_path,im))
# #print(cl7)

# for im in os.listdir(class8_path):  # read image name from folder and append its path into "images" array     
#     cl8.append(os.path.join(class8_path,im))
# #print(cl8)

# for im in os.listdir(class9_path):  # read image name from folder and append its path into "images" array     
#     cl9.append(os.path.join(class9_path,im))
# #print(cl9)
# for im in os.listdir(class10_path):  # read image name from folder and append its path into "images" array     
#     cl10.append(os.path.join(class10_path,im))
# #print(cl10)

cl1_rand = cv2.imread(random.choice(cl1))
cl2_rand = cv2.imread(random.choice(cl2))
cl3_rand = cv2.imread(random.choice(cl3))
cl4_rand = cv2.imread(random.choice(cl4))
cl5_rand = cv2.imread(random.choice(cl5))
cl6_rand = cv2.imread(random.choice(cl6))
cl7_rand = cv2.imread(random.choice(cl7))
cl8_rand = cv2.imread(random.choice(cl8))
cl9_rand = cv2.imread(random.choice(cl9))
cl10_rand = cv2.imread(random.choice(cl10))
plt.subplot(10,1,1)
plt.imshow(cl1_rand)
plt.subplot(10,1,2)
plt.imshow(cl2_rand)
plt.subplot(10,1,3)
plt.imshow(cl3_rand)
plt.subplot(10,1,4)
plt.imshow(cl4_rand)
plt.subplot(10,1,5)
plt.imshow(cl5_rand)
plt.subplot(10,1,6)
plt.imshow(cl6_rand)
plt.subplot(10,1,7)
plt.imshow(cl7_rand)
plt.subplot(10,1,8)
plt.imshow(cl8_rand)
plt.subplot(10,1,9)
plt.imshow(cl9_rand)
plt.subplot(10,1,10)
plt.imshow(cl10_rand)
plt.show()
print(np.subtract(cl1_rand,cl1_rand).shape)
# Out:
# ['../CIFAR-10-images-master/train\\deer\\0000.jpg', '../CIFAR-10-images-master/train\\deer\\0001.jpg', '../CIFAR-10-images-master/train\\deer\\0002.jpg', '../CIFAR-10-images-master/train\\deer\\0003.jpg', '../CIFAR-10-images-master/train\\deer\\0004.jpg', '../CIFAR-10-images-master/train\\deer\\0005.jpg', '../CIFAR-10-images-master/train\\deer\\0006.jpg', '../CIFAR-10-images-master/train\\deer\\0007.jpg', '../CIFAR-10-images-master/train\\deer\\0008.jpg', '../CIFAR-10-images-master/train\\deer\\0009.jpg', '../CIFAR-10-images-master/train\\deer\\0010.jpg', '../CIFAR-10-images-master/train\\deer\\0011.jpg', '../CIFAR-10-images-master/train\\deer\\0012.jpg', '../CIFAR-10-images-master/train\\deer\\0013.jpg', '../CIFAR-10-images-master/train\\deer\\0014.jpg', '../CIFAR-10-images-master/train\\deer\\0015.jpg', '../CIFAR-10-images-master/train\\deer\\0016.jpg', '../CIFAR-10-images-master/train\\deer\\0017.jpg', '../CIFAR-10-images-master/train\\deer\\0018.jpg', '../CIFAR-10-images-master/t
# ...
